# %%
import pandas as pd
import numpy as np

data_train = pd.read_csv("F:/contest/o2o/offline_train.csv")
data_test = pd.read_csv("F:/contest/o2o/test.csv")

# %%
data_train = data_train.sort_values(['User_id','Merchant_id'])
data_test = data_test.sort_values(['User_id','Merchant_id'])

# %%
len(set(data_test.User_id))
# Out:
# 76309

# %%
data_test
# Out:
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  Date_received
# 23866       209         5032       7557          20:5       1.0       20160721
# 23867       209         5032        825          20:5       1.0       20160721
# 23793       215          599       5488          20:1       NaN       20160703
# 61826       316         2436       3992          30:5       0.0       20160721
# 23851       417         3507      12465          50:1       0.0       20160712
# 23831       432         2050      10438        200:20       2.0       20160706
# 61891       448          760      13602          30:5       0.0       20160701
# 61892       448         1482      10927          0.95       0.0       20160710
# 61893       448         1482      10927          0.95       0.0       20160707
# 61894       448         1482      10927          0.95       0.0       20160706
# 61895       448         1482      10927          0.95       0.0       20160704
# ...
