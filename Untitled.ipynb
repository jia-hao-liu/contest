# %%
import pandas as pd
import numpy as np


data_train = pd.read_csv("F:/contest/Tencent/dataset/train.csv")

data_feature = pd.read_csv("F:/contest/Tencent/dataset/userFeature.csv",iterator = True,  header = None)



feature_sample = data_feature.get_chunk(1000000)

feature_sample = feature_sample.sample(n = 100000)

feature_sample['label'] = -1

for i in data_train.aid[data_train.label == 1]:
    if i in feature_sample[0]:
        feature_sample.label[feature_sample[0] == i] = 1
# Out:
# F:\python\venv\anaconda\lib\site-packages\ipykernel\zmqshell.py:537: DtypeWarning: Columns (0,1,2,4,5,6,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

feature_sample.loc(0)

# %%
import matplotlib.pyplot as plt


var = [142.85,165.8, 238.83, 667.14, 2313, 238, 165   ]
DCT = [1.26, 0.68, 0.45, 0.24, 0.10, 0.45, 0.68]
x = [1, 2, 3, 4, 5, 6, 7]

fig = plt.figure()

#plt.plot(x,var)
plt.subplot2grid((1,2),(0,0))
plt.plot(x,var)
plt.title('var')

plt.subplot2grid((1,2),(0,1))
plt.plot(x,DCT)
plt.title('DCT')
plt.show()

aim_path = 'F:/contest/1.png'
plt.savefig('F:/contest/1.png')

plt.clf()

plt.close()

# %%
feature_sample
# Out:
#               0  1  2      3  4  5    6   \
# 781247  50652741  5  1     11  7  1  458
# 793425  31208734  3  1     11  1  0  399
# 478567  40054946  2  2     10  6  1  209
# 483511  61380480  2  2     10  4  1  346
# 876897  35230739  4  1     11  6  0  346
# 197564  66478516  5  1  13 10  7  1  458
# 787634  71753236  4  1     11  6  1  849
# 654430  76551431  1  1  13 10  2  1   83
# 356490  53292457  1  1     10  7  1  705
# 593538  77763722  2  2     10  2  1   94
# 959141  74823970  4  1     11  2  1   94
# 356795  61390247  5  1     10  6  1  458
# 931101  56708879  1  2  13 10  2  1  317
# 22986   19868486  1  1     10  6  1  275
# 585494   1414720  1  1     11  7  0  585
# 809318  14665184  5  1     11  5  1  809
# 113607  17379311  4  1     11  5  1  894
# 120930  19670066  1  1  13 10  6  1  346
# 144599   1220415  1  2  13 10  2  1  494
# 116999  12689434  3  1     11  1  1  769
# 170921  68587939  1  2  13 10  2  0   57
# 156587  11094669  5  1     11  7  0  319
# ...
