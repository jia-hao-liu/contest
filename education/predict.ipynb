# %%
import numpy as np
import pandas as pd

data_train = pd.read_csv("F:/contest/education/dataset/train.csv")
data_test = pd.read_csv("F:/contest/education/dataset/test.csv")

# %%
for i in range(0,10,2):
    data_test.ix[:,i][data_test.ix[:,i] == 'C'] = 1
    data_test.ix[:,i][data_test.ix[:,i] == 'D'] = 2
    data_test.ix[:,i][data_test.ix[:,i] == 'H'] = 3
    data_test.ix[:,i][data_test.ix[:,i] == 'S'] = 4

for i in range(1,10,2):
    data_test.ix[:,i][data_test.ix[:,i] == 'J'] = 11
    data_test.ix[:,i][data_test.ix[:,i] == 'Q'] = 12
    data_test.ix[:,i][data_test.ix[:,i] == 'K'] = 13 

for i in range(0,10):
    data_test.ix[:,i] = data_test.ix[:,i].astype(int)
# Out:
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
for i in range(0,10,2):
    data_train.ix[:,i][data_train.ix[:,i] == 'C'] = 1
    data_train.ix[:,i][data_train.ix[:,i] == 'D'] = 2
    data_train.ix[:,i][data_train.ix[:,i] == 'H'] = 3
    data_train.ix[:,i][data_train.ix[:,i] == 'S'] = 4

for i in range(1,10,2):
    data_train.ix[:,i][data_train.ix[:,i] == 'J'] = 11
    data_train.ix[:,i][data_train.ix[:,i] == 'Q'] = 12
    data_train.ix[:,i][data_train.ix[:,i] == 'K'] = 13 

for i in range(0,11):
    data_train.ix[:,i] = data_train.ix[:,i].astype(int)
# Out:
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
# %%time
# data_train = data_train[['one','thr','fiv', 'sev', 'nin','two','fou','six','eig','ten','ele']]






def countcontinue1(data):
    data = list(set(sorted(data[0:5])))
    now = 0
    start = 0
    maxcon = 0
    while(start < len(data)-1):
        if(data[start+1] - data[start] == 1):
            now += 1
            
        else:
            now = 0
        maxcon = max([maxcon, now])     
        start += 1 
    return maxcon
def countcontinue2(data):
    data = list(set(sorted(data[5:11])))
    now = 0
    start = 0
    maxcon = 0
    while(start < len(data)-1):
        if(data[start+1] - data[start] == 1):
            now += 1
            
        else:
            now = 0
        maxcon = max([maxcon, now])     
        start += 1 
    return maxcon
def countsame1(data):
    return max(data[0:5].value_counts())
def countsame2(data):
    return max(data[5:10].value_counts())

def countsame2_2(data):
    return sorted(list(data[5:10].value_counts()), reverse = True)[1]
def countsame1_2(data):
    if len(list(data[0:5].value_counts())) > 1:
        return sorted(list(data[0:5].value_counts()), reverse = True)[1]
    else:
        return 0
def countgreater10(data):
    return (data>9).sum()

# data_train['continue1'] = data_train.apply(countcontinue1, axis = 1)
data_train['continue2'] = data_train.apply(countcontinue2,axis = 1)
# data_train['same1'] = data_train.apply(countsame1,axis = 1)
# data_train['same2'] = data_train.apply(countsame2,axis = 1)
# data_train['same1_2'] = data_train.apply(countsame1_2,axis =1)
# data_train['same2_2'] = data_train.apply(countsame2_2,axis =1)
# data_train['greater10'] = data_train.apply(countgreater10, axis = 1)
# Out:
# Wall time: 4.15 s

# %%
# %%time
# data_test = data_test[['one','thr','fiv', 'sev', 'nin','two','fou','six','eig','ten']]






def countcontinue1(data):
    data = list(set(sorted(data[0:5])))
    now = 0
    start = 0
    maxcon = 0
    while(start < len(data)-1):
        if(data[start+1] - data[start] == 1):
            now += 1
            
        else:
            now = 0
        maxcon = max([maxcon, now])     
        start += 1 
    return maxcon
def countcontinue2(data):
    data = list(set(sorted(data[5:11])))
    now = 0
    start = 0
    maxcon = 0
    while(start < len(data)-1):
        if(data[start+1] - data[start] == 1):
            now += 1
            
        else:
            now = 0
        maxcon = max([maxcon, now])     
        start += 1 
    return maxcon
def countsame1(data):
    return max(data[0:5].value_counts())
def countsame2(data):
    return max(data[5:10].value_counts())

def countsame2_2(data):
    return sorted(list(data[5:10].value_counts()), reverse = True)[1]
def countsame1_2(data):
    if len(list(data[0:5].value_counts())) > 1:
        return sorted(list(data[0:5].value_counts()), reverse = True)[1]
    else:
        return 0

# data_test['continue1'] = data_test.apply(countcontinue1, axis = 1)
data_test['continue2'] = data_test.apply(countcontinue2,axis = 1)
# data_test['same1'] = data_test.apply(countsame1,axis = 1)
# data_test['same2'] = data_test.apply(countsame2,axis = 1)
# data_test['same1_2'] = data_test.apply(countsame1_2,axis =1)
# data_test['same2_2'] = data_test.apply(countsame2_2,axis =1)


# def countgreater10(data):
#     return (data>9).sum()
# data_test['greater10'] = data_test.apply(countgreater10, axis = 1)
# Out:
# Wall time: 16 s

# %%
# %%time
import lightgbm as lgb
LGBM = lgb.LGBMClassifier(
                         max_depth=7, 
                         n_estimators=100, 
                         learning_rate=0.1, 
                         num_leaves=63, 
                         min_samples_split=2)
df = data_train.as_matrix()

X = df[:,12:]



y = list(df[:,11])
LGBM.fit(X,y)
# Out:
# Wall time: 1.93 s

# %%
res12 = LGBM.predict(data_test.as_matrix()[:,11:18])
# Out:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
def to14(data):
    if data.continue2 == 3 and data.greater10 == 4 and (1 in data[5:10].values) :
        return 14
    else:
        return -1
data_train['1to14'] = data_train.apply(to14, axis = 1)

# %%
test_columns = list(data_test.columns)[:-1]
test_columns.insert(test_columns.index('continue1'), '1to14')
data_test = data_test[test_columns]

# %%
for i in range(10):
    print(i, (res12==i).sum()/100000)
    print(i,  data_train[data_train.ele == i].shape[0]/25010)
# Out:
# 0 0.50182
# 0 0.4995201919232307
# 1 0.02116
# 1 0.020511795281887246
# 2 0.04629
# 2 0.04822071171531388
# 3 0.42321
# 3 0.42379048380647744
# 4 0.00373
# 4 0.003718512594962015
# 5 0.00211
# 5 0.0021591363454618153
# 6 0.0014
# 6 0.0014394242303078768
# 7 0.00027
# 7 0.0009596161535385846
# 8 0.0
# 8 0.00019992003198720512
# 9 1e-05
# 9 0.00019992003198720512

# %%
data_test[data_test.continue2 == 4]
# Out:
#        one  thr  fiv  sev  nin  two  fou  six  eig  ten  1to14  continue1  \
# 6        1    4    4    3    3    7    8    6    9   10     -1          1
# 424      3    3    4    3    1    4    2    3    6    5     -1          1
# 513      1    4    4    2    1    4    6    3    5    2     -1          1
# 731      4    3    4    2    1   13   12   10   11    9     -1          3
# 1149     2    1    4    1    1    3    5    2    4    1     -1          1
# 1659     1    4    4    2    3    2    5    4    3    6     -1          3
# 1801     2    3    1    1    2   11   10    8    9   12     -1          2
# 2102     3    2    3    1    1    3    6    5    7    4     -1          2
# 2333     3    1    3    3    1    4    1    3    5    2     -1          0
# 2979     1    3    3    3    1    6    4    7    3    5     -1          0
# 3083     2    2    4    2    3    4    8    6    5    7     -1          2
# 3194     4    1    2    3    2    5    4    3    6    2     -1          3
# ...

# %%
data_train[data_train.continue2 == 4]
# Out:
#        one  thr  fiv  sev  nin  two  fou  six  eig  ten  1to14  ele  \
# 0        3    3    3    3    3   10   11   12   13    1     14    9
# 1        4    4    4    4    4   11   13   12   10    1     14    9
# 2        2    2    2    2    2   12   11   10   13    1     14    9
# 3        1    1    1    1    1   10   11   13    1   12     14    9
# 4        1    1    1    1    1    1   13   11   12   10     14    9
# 5        3    3    3    3    3    2    4    3    5    6     -1    8
# 6        3    3    3    3    3    9   12   11   10   13     -1    8
# 7        4    4    4    4    4    1    2    4    3    5     -1    8
# 8        2    2    2    2    2    5    6    7    9    8     -1    8
# 9        1    1    1    1    1    1    4    3    2    5     -1    8
# 16       3    3    2    3    2    4    1    5    3    2     -1    4
# 402      3    2    1    2    4   11   12    9   10   13     -1    4
# 769      2    3    2    1    1    9   10    7   11    8     -1    4
# ...

# %%
# data_train[data_train.ele == 4]
# data_test[data_test.label == 4]
# data_train = pd.concat([data_train,data_train[data_train.ele == 7]]).reset_index(drop = True)
pd.DataFrame(res12).to_csv("F:/contest/education/dsjyycxds_preliminary.txt", index = False)

# %%
data_train.loc[25010] = data_train.loc[8466]
data_train.loc[25011] = data_train.loc[8466]
data_train.loc[25012] = data_train.loc[8466]
data_train.loc[25013] = data_train.loc[8466]
data_train.loc[25014] = data_train.loc[8466]
data_train.loc[25015] = data_train.loc[8466]
data_train.loc[25016] = data_train.loc[8466]
data_train.loc[25016].continue2 = 1
data_train.loc[25015].continue2 = 1

# %%
import numpy as np
import pandas as pd

data_train = pd.read_csv("F:/contest/education/dsjyycxds_preliminary.txt")
data_test = pd.read_csv("F:/contest/education/99.9.txt")

# %%
count = 0
for i in range(99999):
    if data_train.iloc[i,0] != data_test.iloc[i,0]:
        count += 1
count
# Out:
# 27

# %%
data_train[data_train.ele == 5].shape
# Out:
# (54, 18)

# %%
data_train
# Out:
#        one  thr  fiv  sev  nin  two  fou  six  eig  ten  1to14  ele  \
# 0        3    3    3    3    3   10   11   12   13    1     14    9
# 1        4    4    4    4    4   11   13   12   10    1     14    9
# 2        2    2    2    2    2   12   11   10   13    1     14    9
# 3        1    1    1    1    1   10   11   13    1   12     14    9
# 4        1    1    1    1    1    1   13   11   12   10     14    9
# 5        3    3    3    3    3    2    4    3    5    6     -1    8
# 6        3    3    3    3    3    9   12   11   10   13     -1    8
# 7        4    4    4    4    4    1    2    4    3    5     -1    8
# 8        2    2    2    2    2    5    6    7    9    8     -1    8
# 9        1    1    1    1    1    1    4    3    2    5     -1    8
# 10       3    4    3    2    4    1    1    5    9    3     -1    3
# 11       4    4    4    1    1    6    1    4   13    9     -1    0
# 12       3    1    3    3    2   10    6    1    2    8     -1    0
# ...

# %%
for i in range(10):
    print(i, (res==i).sum()/100000)
    print(i,  data_train[data_train.ele == i].shape[0]/25010)
# Out:
# 0 0.5022
# 0 0.4995201919232307
# 1 0.02116
# 1 0.020511795281887246
# 2 0.04629
# 2 0.04822071171531388
# 3 0.42321
# 3 0.42379048380647744
# 4 0.00335
# 4 0.003718512594962015
# 5 0.002
# 5 0.0021591363454618153
# 6 0.0014
# 6 0.0014394242303078768
# 7 0.00027
# 7 0.0009596161535385846
# 8 1e-05
# 8 0.00019992003198720512
# 9 0.00011
# 9 0.00019992003198720512

# %%
for i in range(10):
    print(i, (res1==i).sum()/100000)
    print(i,  data_train[data_train.ele == i].shape[0]/25010)
# Out:
# 0 0.5022
# 0 0.4995201919232307
# 1 0.02143
# 1 0.020511795281887246
# 2 0.04629
# 2 0.04822071171531388
# 3 0.42321
# 3 0.42379048380647744
# 4 0.00333
# 4 0.003718512594962015
# 5 0.0021
# 5 0.0021591363454618153
# 6 0.0014
# 6 0.0014394242303078768
# 7 0.0
# 7 0.00023990403838464614
# 8 3e-05
# 8 0.00019992003198720512
# 9 1e-05
# 9 0.00019992003198720512

# %% [markdown]
# 9,8,6,5,1

# %%
cmp1 = pd.read_csv("F:/contest/education/99.959.txt")

# %%
count = 0
for i in range(100000):
    if cmp1[i] != res12[i]:
        count += 1
count
# Out:
# 42
