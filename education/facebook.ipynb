# %%
import pandas as pd
import numpy as np

data_train = pd.read_csv("F:/contest/education/dataset/train.csv")
data_test = pd.read_csv("F:/contest/education/dataset/test.csv")
for i in range(0,10,2):
    data_train.ix[:,i][data_train.ix[:,i] == 'C'] = 1
    data_train.ix[:,i][data_train.ix[:,i] == 'D'] = 2
    data_train.ix[:,i][data_train.ix[:,i] == 'H'] = 3
    data_train.ix[:,i][data_train.ix[:,i] == 'S'] = 4

for i in range(1,10,2):
    data_train.ix[:,i][data_train.ix[:,i] == 'J'] = 11
    data_train.ix[:,i][data_train.ix[:,i] == 'Q'] = 12
    data_train.ix[:,i][data_train.ix[:,i] == 'K'] = 13 

for i in range(0,11):
    data_train.ix[:,i] = data_train.ix[:,i].astype(int)
# Out:
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   import sys
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
# Out:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# <module 'matplotlib.pyplot' from 'F:\\python\\venv\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# %%time

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import ExtraTreeClassifier

df = data_train.as_matrix()

X = df[:,11:15]

#X = np.column_stack((df[:,0:10],df[:,11:13]))

y = list(df[:,10])

clf = RandomForestClassifier(random_state=0, n_estimators=100, n_jobs=-1)
clf.fit(X,y)

plot_learning_curve(clf, 'learning_curve', X, y, ylim=None, cv=None,
                     train_sizes=np.linspace(.1, 1.0, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>()
#
# NameError: name 'plot_learning_curve' is not defined

# %%
# %%time
import lightgbm as lgb
LGBM = lgb.LGBMClassifier(
                         max_depth=7, 
                         n_estimators=100, 
                         learning_rate=0.1, 
                         num_leaves=63, 
                         min_samples_split=2)
df = data_train.as_matrix()

X = df[:,11:17]

#X = np.column_stack((df[:,0:10],df[:,11:13]))

y = list(df[:,10])
LGBM.fit(X,y)
# Out:
# Wall time: 1.96 s

# %%
result = LGBM.predict(data_test.as_matrix()[:,10:16])
data_test['label'] = result
# Out:
# F:\python\venv\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
for i in range(0,10,2):
    data_train.ix[:,i][data_train.ix[:,i] == 'C'] = 1
    data_train.ix[:,i][data_train.ix[:,i] == 'D'] = 2
    data_train.ix[:,i][data_train.ix[:,i] == 'H'] = 3
    data_train.ix[:,i][data_train.ix[:,i] == 'S'] = 4

for i in range(1,10,2):
    data_train.ix[:,i][data_train.ix[:,i] == 'J'] = 11
    data_train.ix[:,i][data_train.ix[:,i] == 'Q'] = 12
    data_train.ix[:,i][data_train.ix[:,i] == 'K'] = 13 
    
for i in range(0,10):
    data_train.ix[:,i] = data_train.ix[:,i].astype(int)
# Out:
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
#data_train.sort_index(by = 'ele')[['two','fou','six','eig','ten','ele']]
#[['one','thr','fiv', 'sev', 'nin', 'ele']]
# data_train = data_train[['one','thr','fiv', 'sev', 'nin','two','fou','six','eig','ten', 'ele']]
# data_train[data_train.ele == ]
data_test = pd.read_csv("F:/contest/education/dataset/test.csv")

# %%
dt = data_train
data_train = data_test

# %%
data_test = data_train
data_train = dt

# %%
# %%time
data_train = data_train[['one','thr','fiv', 'sev', 'nin','two','fou','six','eig','ten','ele']]






def countcontinue1(data):
    data = list(set(sorted(data[0:5])))
    now = 0
    start = 0
    maxcon = 0
    while(start < len(data)-1):
        if(data[start+1] - data[start] == 1):
            now += 1
            
        else:
            now = 0
        maxcon = max([maxcon, now])     
        start += 1 
    return maxcon
def countcontinue2(data):
    data = list(set(sorted(data[5:10])))
    now = 0
    start = 0
    maxcon = 0
    while(start < len(data)-1):
        if(data[start+1] - data[start] == 1):
            now += 1
            
        else:
            now = 0
        maxcon = max([maxcon, now])     
        start += 1 
    return maxcon
def countsame1(data):
    return max(data[0:5].value_counts())
def countsame2(data):
    return max(data[5:10].value_counts())

def countsame2_2(data):
    return sorted(list(data[5:10].value_counts()), reverse = True)[1]
def countsame1_2(data):
    if len(list(data[0:5].value_counts())) > 1:
        return sorted(list(data[0:5].value_counts()), reverse = True)[1]
    else:
        return 0


data_train['continue1'] = data_train.apply(countcontinue1, axis = 1)
data_train['continue2'] = data_train.apply(countcontinue2,axis = 1)
data_train['same1'] = data_train.apply(countsame1,axis = 1)
data_train['same2'] = data_train.apply(countsame2,axis = 1)
data_train['same1_2'] = data_train.apply(countsame1_2,axis =1)
data_train['same2_2'] = data_train.apply(countsame2_2,axis =1)
# Out:
# Wall time: 30.7 s

# %%
# %%time
def countsame2_2(data):
    return sorted(list(data[5:10].value_counts()), reverse = True)[1]
def countsame1_2(data):
    if len(list(data[0:5].value_counts())) > 1:
        return sorted(list(data[0:5].value_counts()), reverse = True)[1]
    else:
        return 0


data_train['same1_2'] = data_train.apply(countsame1_2,axis =1)
data_train['same2_2'] = data_train.apply(countsame2_2,axis =1)
# Out:
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# Wall time: 4min 16s
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
count = 0
for i in range(100000):
    if kmeans.labels_[i] == 9:
        count += 1
count
# Out:
# 8657

# %%
sorted(list(data_train.iloc[10,5:10].value_counts()), reverse = True)[1]
# Out:
# 1

# %%
data_train[data_train.continue1 == 4]
# Out:
#        one  thr  fiv  sev  nin  two  fou  six  eig  ten  continue1  continue2  \
# 19       1    1    1    1    1    9    2    5   12    4          4          1
# 816      3    3    3    3    3    7    6    9   13    8          4          3
# 962      1    1    1    1    1    5   13    2   12    4          4          2
# 1481     2    2    2    2    2    3   11    4    6    2          4          2
# 2300     4    4    4    4    4    4    5   12   10    2          4          2
# 2510     1    1    1    1    1    8    1    6    4    2          4          3
# 2802     1    1    1    1    1    6   13    2    4    3          4          2
# 2874     1    1    1    1    1    1    8   13    5    6          4          1
# 3375     3    3    3    3    3   10    2    5    1    3          4          2
# 4370     2    2    2    2    2    9    5    4    8   12          4          2
# 4486     2    2    2    2    2    8    6    5    7   12          4          3
# 4645     4    4    4    4    4    5   10   11   13    8          4          2
# 4696     3    3    3    3    3    5    9    4    7   13          4          2
# 4905     3    3    3    3    3    4    9    6   12   11          4          2
# 5177     2    2    2    2    2    1    8    5   11   10          4          1
# 7138     3    3    3    3    3    3    9   11    5   10          4          2
# 7230     1    1    1    1    1    5   13    4    2    6          4          2
# 7282     4    4    4    4    4   10    4   12    8    7          4          2
# 8896     3    3    3    3    3    7    2    6   13    1          4          2
# 24789    1    1    2    1    3    9   12    7    7   12    2          2
# 24794    3    4    4    1    1    8   10    4    8   10    2          1
# 24846    4    1    3    2    3   10    4    6    6   10    2          3
# 24852    1    1    2    2    2   11    7    7   11   10    2          1
# 24873    4    1    2    3    1   11   13   11    1    1    2          3
# 24902    4    4    1    2    3    2    4    2    7    4    2          3
# 24916    4    3    1    4    3    5    4   12   12    5    2          1
# 24925    2    2    2    3    3    5    3    4    3    4    2          1
# 24960    2    4    4    3    2    2    5    6    2    5    2          2
#
#        continue2  same1  same2  same2_2  same1_2
# 59             0      2      2        2        1
# 75             0      2      2        2        1
# 77             1      2      2        2        1
# 96             0      2      2        2        1
# 159            0      3      2        2        1
# 246            0      2      2        2        2
# 248            1      3      2        2        1
# 251            1      2      2        2        1
# 288            0      2      2        2        2
# 326            0      3      2        2        2
# 335            0      2      2        2        1
# 341            0      3      2        2        1
# 364            1      2      2        2        2
# 380            1      3      2        2        1
# 411            0      2      2        2        2
# 420            0      2      2        2        2
# 450            0      2      2        2        2
# 454            0      2      2        2        2
# 469            0      2      2        2        1
# 495            0      2      2        2        2
# 504            1      2      2        2        2
# 511            0      2      2        2        1
# 523            1      3      2        2        2
# 546            0      3      2        2        1
# 552            0      2      2        2        2
# 627            0      2      2        2        1
# 639            1      2      2        2        1
# 687            0      3      2        2        1
# 690            0      3      2        2        1
# 726            1      2      2        2        2
# ...          ...    ...    ...      ...      ...
# 24386          0      2      2        2        1
# 24388          0      2      2        2        2
# 24464          1      2      2        2        2
# 24467          0      3      2        2        1
# 24472          1      2      2        2        2
# 24476          0      2      2        2        1
# 24516          1      2      2        2        1
# 24540          1      2      2        2        2
# 24543          0      2      2        2        2
# 24545          1      2      2        2        2
# 24566          1      2      2        2        2
# 24610          0      3      2        2        2
# 24639          0      3      2        2        1
# 24657          0      2      2        2        2
# 24674          0      3      2        2        2
# 24679          0      2      2        2        2
# 24684          0      3      2        2        1
# 24689          1      2      2        2        2
# 24724          0      2      2        2        2
# 24734          1      3      2        2        2
# 24779          0      2      2        2        2
# 24789          0      3      2        2        1
# 24794          0      2      2        2        2
# 24846          0      2      2        2        1
# 24852          1      3      2        2        2
# 24873          0      2      2        2        1
# 24902          0      2      2        2        1
# 24916          1      2      2        2        2
# 24925          2      3      2        2        2
# 24960          1      2      2        2        2
#
# [1206 rows x 17 columns]

# %%
# %%time
def countcontinue2(data):
    data = sorted(data[0:5])
    now = 0
    start = 0
    maxcon = 0
    while(start < 4):
        if(data[start+1] - data[start] == 1):
            now += 1
            
        else:
            now = 0
        maxcon = max([maxcon, now])     
        start += 1 
    return maxcon

data_train['continue1'] =  data_train.apply(countcontinue2,axis = 1)
data_train['continue2'] =  data_train['continue']
# Out:
# Wall time: 3.7 s

# %%
# tmp = data_train['same2_2']
# data_train = data_train.drop(['same2_2'], axis =1 )
# data_train.insert(16,'same2_2', tmp)

# %%
i = 9
print(data_train[data_train.ele == i].shape)
print(data_test[data_test.label == i].shape)
# Out:
# (5, 17)
# (11, 17)
