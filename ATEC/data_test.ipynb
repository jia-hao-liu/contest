# %%
# Out:
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Wall time: 38.6 s

# %%
# Out:
# F:\python\venv\anaconda\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   if sys.path[0] == '':
# F:\python\venv\anaconda\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
import numpy as np
import pandas as pd

data_test = pd.read_csv("F:/contest/ATEC/test.csv")

count = 0
miss = []
for i in data_test.columns:

    miss.append((i,data_test[i].isnull().sum()/491688))
miss
# Out:
# [('id', 0.0),
#  ('date', 0.0),
#  ('f1', 0.0),
#  ('f2', 0.0),
#  ('f3', 0.0),
#  ('f4', 0.0),
#  ('f5', 0.25028880102829437),
#  ('f6', 0.0),
#  ('f7', 0.0),
#  ('f8', 0.0),
#  ('f9', 0.0),
#  ('f10', 0.0),
#  ('f11', 0.0),
#  ('f12', 0.0),
#  ('f13', 0.0),
#  ('f14', 0.0),
#  ('f15', 0.0),
#  ('f16', 0.0),
#  ('f17', 0.0),
#  ('f18', 0.0),
#  ('f19', 0.0),
#  ('f20', 0.24583272319031582),
#  ('f21', 0.24583272319031582),
#  ('f22', 0.24583272319031582),
#  ('f23', 0.24583272319031582),
#  ('f24', 0.24589983892224337),
#  ('f25', 0.24589983892224337),
#  ('f26', 0.24589983892224337),
#  ('f27', 0.24589983892224337),
#  ('f28', 0.24930850458014026),
#  ('f29', 0.24930850458014026),
#  ('f30', 0.24930850458014026),
#  ('f31', 0.24930850458014026),
#  ('f32', 0.3528070646426189),
#  ('f33', 0.3528070646426189),
#  ('f34', 0.3528070646426189),
#  ('f35', 0.3528070646426189),
#  ('f36', 0.9459962415190121),
#  ('f37', 0.9459962415190121),
#  ('f38', 0.9459962415190121),
# ...

# %% [markdown]
# 测试数据缺失值明显更多

# %%
data_train = pd.read_csv("F:/contest/ATEC/train.csv")


mis = []
for i in data_train.columns:

    mis.append((i,data_train[i].isnull().sum()/994731))
mis
# Out:
# [('id', 0.0),
#  ('label', 0.0),
#  ('date', 0.0),
#  ('f1', 0.0),
#  ('f2', 0.0),
#  ('f3', 0.0),
#  ('f4', 0.0),
#  ('f5', 0.20088345492399454),
#  ('f6', 0.0),
#  ('f7', 0.0),
#  ('f8', 0.0),
#  ('f9', 0.0),
#  ('f10', 0.0),
#  ('f11', 0.0),
#  ('f12', 0.0),
#  ('f13', 0.0),
#  ('f14', 0.0),
#  ('f15', 0.0),
#  ('f16', 0.0),
#  ('f17', 0.0),
#  ('f18', 0.0),
#  ('f19', 0.0),
#  ('f20', 0.2085468332644705),
#  ('f21', 0.2085468332644705),
#  ('f22', 0.2085468332644705),
#  ('f23', 0.2085468332644705),
#  ('f24', 0.20868455894106044),
#  ('f25', 0.20868455894106044),
#  ('f26', 0.20868455894106044),
#  ('f27', 0.20868455894106044),
#  ('f28', 0.21215383857545406),
#  ('f29', 0.21215383857545406),
#  ('f30', 0.21215383857545406),
#  ('f31', 0.21215383857545406),
#  ('f32', 0.3436979444694093),
#  ('f33', 0.3436979444694093),
#  ('f34', 0.3436979444694093),
#  ('f35', 0.3436979444694093),
#  ('f36', 0.9306847780957866),
#  ('f37', 0.9306847780957866),
#  ('f38', 0.9306847780957866),
# ...

# %%
data_train.iloc[:,299:350].to_csv("F:/contest/ATEC/data_test_0fill.csv", index = False)

# %%
positive = data_train[data_train.label == 1].iloc[0:100,:]
negative = data_train[data_train.label == 0].iloc[0:100,:]
pos = []
neg = []
for i in range(100):
    pos.append(positive.iloc[i,:].isnull().sum())
    neg.append(negative.iloc[i,:].isnull().sum())
# Out:
# [109,
#  12,
#  231,
#  12,
#  12,
#  231,
#  231,
#  12,
#  12,
#  12,
#  231,
#  12,
#  231,
#  12,
#  12,
#  12,
#  162,
#  12,
#  12,
#  18,
#  231,
#  161,
#  18,
#  231,
#  231,
#  12,
#  231,
#  12,
#  12,
#  99,
#  12,
#  12,
#  109,
#  12,
#  231,
#  99,
#  12,
#  12,
#  12,
#  12,
#  162,
#  231,
#  12,
#  109,
#  12,
#  12,
#  231,
#  12,
#  12,
#  231,
#  12,
#  231,
#  12,
#  12,
#  109,
#  231,
#  231,
#  231,
#  12,
#  99,
#  161,
#  231,
#  12,
#  99,
#  162,
#  12,
#  231,
#  12,
#  109,
#  109,
#  12,
#  231,
#  99,
#  12,
#  12,
#  231,
#  231,
#  231,
#  231,
#  231,
#  12,
#  231,
#  231,
#  12,
#  231,
#  231,
#  231,
#  231,
#  162,
#  12,
#  231,
#  12,
#  231,
#  12,
#  12,
#  12,
#  109,
#  12,
#  231,
#  231]

# %%
# %%time
def getmissnum(data):
    return data[0:21].sum()
data_train['miss'] = data_train.apply(getmissnum,axis = 1)
# Out:
# Wall time: 2min 22s

# %%
import pandas as pd
import numpy as np

data_train = pd.read_csv("F:/contest/ATEC/data_train1.csv")
data_nonlabel = data_train[data_train.label == -1]

# %%
def getmissnum(data):
    return data[0:21].sum()
sum(data_train[data_train.label == 1].apply(getmissnum,axis = 1))/12122
# Out:
# 1.979541329813562

# %%
# %%time
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(data_nonlabel.iloc[:,1:50])
# Out:
# Wall time: 799 ms

# %%
data_train[data_train.miss == -21]
# Out:
#         ifexist5  ifexist20-23  ifexist24-27  ifexist28-31  ifexist32-35  \
# 280           -1            -1            -1            -1            -1
# 438           -1            -1            -1            -1            -1
# 1051          -1            -1            -1            -1            -1
# 1359          -1            -1            -1            -1            -1
# 1658          -1            -1            -1            -1            -1
# 1868          -1            -1            -1            -1            -1
# 2112          -1            -1            -1            -1            -1
# 2545          -1            -1            -1            -1            -1
# 3439          -1            -1            -1            -1            -1
# 3479          -1            -1            -1            -1            -1
# 4164          -1            -1            -1            -1            -1
# 5019          -1            -1            -1            -1            -1
# ...

# %%
data_train['miss'] = data_train.apply(lambda x: x[0:21].sum(), axis = 1)

# %%
def getmissnum(df):
    count = 0
    for i in df[1:22]:
        if i == -1:
            count += 1
    return count

# %%
data_nonlabel.miss[data_nonlabel.label == 0].sum()/3164
# Out:
# 17.648546144121365

# %%
data_nonlabel[data_nonlabel.label == 0]
# Out:
#         label  ifexist5  ifexist20-23  ifexist24-27  ifexist28-31  \
# 73          0         1             1             1             1
# 195         0         1             1             1             1
# 215         0         1             1             1             1
# 307         0         1             1             1             1
# 314         0         1             1             1             1
# 424         0         1             1             1             1
# 425         0         1             1             1             1
# 484         0         1             1             1             1
# 654         0         1             1             1             1
# 685         0         1             1             1             1
# 870         0         1             1             1             1
# 957         0         1             1             1             1
# 2034        0         1             1             1             1
# ...

# %%
data_train.to_csv("F:/contest/ATEC/data_test_0fill.csv", index = False)
